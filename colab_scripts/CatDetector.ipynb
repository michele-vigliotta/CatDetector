# %%
### 1. Mount Google Drive ###

from google.colab import drive

drive.mount('/content/gdrive')

# %%
### 2. Prepare data ###

# !scp '/content/gdrive/My Drive/CatDetector/Dataset.zip' '/content/Dataset.zip'

# !unzip '/content/Dataset.zip' -d '/content/'

# %%
### 3. Install packages ###

# !pip install ultralytics

# %%
### 4. Train model ###

import os

from ultralytics import YOLO


config_path = '/content/gdrive/My Drive/CatDetector/config.yaml'

# Load a model
model = YOLO("yolo11n.pt")  # uso modello preaddestrato COCO, prestazioni piú alte

# Train the model
model.train(data=config_path, epochs=150, batch=32, device='0', patience=20, save_period=25, cache='ram', amp=True)  # train the model

# %%
### 4. Train model da zero###

import os

from ultralytics import YOLO


config_path = '/content/gdrive/My Drive/CatDetector/config.yaml'

# Load a model
model = YOLO("yolo11n.yaml")  # uso solo architettura, non addestrato. Mi aspetto prestazioni piú basse

# Train the model
model.train(data=config_path, epochs=150, batch=32, device='0', patience=20, save_period=25, cache='ram', amp=True, )  # train the model
# Out:
# Ultralytics 8.3.167 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
import os
import shutil

shutil.rmtree('/content/runs')
os.remove('/content/runs.zip')

# %%
### 5. Download results ###

from google.colab import files


# !zip -r /content/runs.zip /content/runs

files.download('/content/runs.zip')
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/train/ (stored 0%)
#   adding: content/runs/detect/train/train_batch0.jpg (deflated 4%)
#   adding: content/runs/detect/train/BoxR_curve.png (deflated 15%)
#   adding: content/runs/detect/train/results.csv (deflated 61%)
#   adding: content/runs/detect/train/labels.jpg (deflated 28%)
#   adding: content/runs/detect/train/confusion_matrix_normalized.png (deflated 37%)
#   adding: content/runs/detect/train/val_batch0_labels.jpg (deflated 7%)
#   adding: content/runs/detect/train/train_batch1.jpg (deflated 3%)
#   adding: content/runs/detect/train/BoxF1_curve.png (deflated 15%)
#   adding: content/runs/detect/train/BoxP_curve.png (deflated 17%)
#   adding: content/runs/detect/train/BoxPR_curve.png (deflated 24%)
#   adding: content/runs/detect/train/val_batch1_pred.jpg (deflated 7%)
#   adding: content/runs/detect/train/confusion_matrix.png (deflated 38%)
# ...
